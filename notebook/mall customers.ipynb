# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Gender              200 non-null    object
#  2   Age                 200 non-null    int64
#  3   Annual_Income_(k$)  200 non-null    int64
#  4   Spending_Score      200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
dataset.isnull().any()
# Out:
# CustomerID            False
# Gender                False
# Age                   False
# Annual_Income_(k$)    False
# Spending_Score        False
# dtype: bool

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual_Income_(k$)', 'Spending_Score'], dtype='object')

# %%
dataset.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dataset_male=dataset['Gender']=='Male'
total_male=dataset_male.sum()
total_male
# Out:
# 88

# %%
###piechart visualisation
labels=['FEMALE','MALE']
size=dataset['Gender'].value_counts()
explode=[0,0.5]
colors=['Gray','Cyan']
fig,ax=plt.subplots()
plt.rcParams['figure.figsize']=(5,5)
plt.pie(size,labels=labels,explode=explode,colors=colors,shadow=True,autopct='%1.1f%%')
plt.savefig("artifacts/piechart.pdf",format='pdf')
plt.show()

# %%
###find out what age group has the higher income
age = dataset['Age']
annual_in=dataset['Annual_Income_(k$)']



plt.hist(age,annual_in,orientation='horizontal')

plt.savefig("images/hist.png")

plt.show()

# %%
import seaborn as sns
age = dataset['Age']
annual_in=dataset['Annual_Income_(k$)']
plt.figure(figsize=(16,4))



sns.boxenplot(x=age,y=annual_in)
plt.title('Age and income')
plt.grid(True)
plt.savefig("artifacts/boxenplot.pdf",format='pdf')

plt.show()

# %%
##checking the top five rows to get an idea of the dataset
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
##cheking how many females and males in the dataset
dataset['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
dataset['Age'].mean()
# Out:
# 38.85

# %%
dataset['Age'].max()
# Out:
# 70

# %%
dataset['Age'].min()
# Out:
# 18

# %%
##checking for empty cells on the dataframe 
f=dataset['Spending_Score'].isnull()
f.value_counts()
# Out:
# False    200
# Name: Spending_Score, dtype: int64

# %%
dataset['Age'].median()
# Out:
# 36.0

# %%
dataset['Age'].mode()
# Out:
# 0    32
# dtype: int64

# %%
dataset['Annual_Income_(k$)'].max()
# Out:
# 137

# %%
dataset['Annual_Income_(k$)'].min()
# Out:
# 15

# %%
dataset[dataset['Annual_Income_(k$)']==137]
# Out:
#      CustomerID Gender  Age  Annual_Income_(k$)  Spending_Score
# 198         199   Male   32                 137              18
# 199         200   Male   30                 137              83

# %%
dataset['Spending_Score'].max()
# Out:
# 99

# %%
dataset[dataset['Spending_Score']==99]
# Out:
#     CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 11          12  Female   35                  19              99

# %%
dataset.describe()
# Out:
#        CustomerID         Age  Annual_Income_(k$)  Spending_Score
# count  200.000000  200.000000          200.000000      200.000000
# mean   100.500000   38.850000           60.560000       50.200000
# std     57.879185   13.969007           26.264721       25.823522
# min      1.000000   18.000000           15.000000        1.000000
# 25%     50.750000   28.750000           41.500000       34.750000
# 50%    100.500000   36.000000           61.500000       50.000000
# 75%    150.250000   49.000000           78.000000       73.000000
# max    200.000000   70.000000          137.000000       99.000000

# %%
#let say 80 is a great spending score,let check for the genders that spends more when they come to the mull
spendsmore=dataset[dataset['Spending_Score']>80]

# %%
spendsmore
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 1             2    Male   21                  15              81
# 7             8  Female   23                  18              94
# 11           12  Female   35                  19              99
# 19           20  Female   35                  23              98
# 25           26    Male   29                  28              82
# 29           30  Female   23                  29              87
# 33           34    Male   18                  33              92
# 35           36  Female   21                  33              81
# 41           42    Male   24                  38              92
# 123         124    Male   39                  69              91
# 127         128    Male   40                  71              95
# 135         136  Female   29                  73              88
# 141         142    Male   32                  75              93
# ...

# %%
spendsmore['Age'].mean()
# Out:
# 30.6

# %%
spendsmore['Age'].max()
# Out:
# 40

# %%
spendsmore2=dataset[dataset['Spending_Score']<50]

# %%
spendsmore2.head(50)
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 2             3  Female   20                  16               6
# 4             5  Female   31                  17              40
# 6             7  Female   35                  18               6
# 8             9    Male   64                  19               3
# 10           11    Male   67                  19              14
# 12           13  Female   58                  20              15
# 14           15    Male   37                  20              13
# 16           17  Female   35                  21              35
# 18           19    Male   52                  23              29
# 20           21    Male   35                  24              35
# 22           23  Female   46                  25               5
# 24           25  Female   54                  28              14
# ...

# %%
fo=spendsmore2[spendsmore2['Age']>25]
fo.head(50)
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 4             5  Female   31                  17              40
# 6             7  Female   35                  18               6
# 8             9    Male   64                  19               3
# 10           11    Male   67                  19              14
# 12           13  Female   58                  20              15
# 14           15    Male   37                  20              13
# 16           17  Female   35                  21              35
# 18           19    Male   52                  23              29
# 20           21    Male   35                  24              35
# 22           23  Female   46                  25               5
# 24           25  Female   54                  28              14
# 26           27  Female   45                  28              32
# 28           29  Female   40                  29              31
# ...

# %%
spendsmore2['Annual_Income_(k$)'].value_counts()
# Out:
# 78     6
# 54     6
# 60     4
# 62     3
# 87     3
# 71     3
# 63     3
# 40     3
# 67     2
# 65     2
# 64     2
# 61     2
# 77     2
# 48     2
# 73     2
# 39     2
# 43     2
# 88     2
# 103    2
# 33     2
# 19     2
# 20     2
# 28     2
# 126    1
# 75     1
# 120    1
# 113    1
# 76     1
# 99     1
# 101    1
# 93     1
# 98     1
# 79     1
# 81     1
# 97     1
# 85     1
# 86     1
# 74     1
# 15     1
# 72     1
# 34     1
# 17     1
# 18     1
# 21     1
# 23     1
# 24     1
# 25     1
# 29     1
# 30     1
# 37     1
# 70     1
# 38     1
# 44     1
# 46     1
# 49     1
# 50     1
# 58     1
# 59     1
# 16     1
# 137    1
# Name: Annual_Income_(k$), dtype: int64

# %%
spendsmore3=dataset[dataset['Spending_Score']>90]

# %%
spendsmore3
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score
# 7             8  Female   23                  18              94
# 11           12  Female   35                  19              99
# 19           20  Female   35                  23              98
# 33           34    Male   18                  33              92
# 41           42    Male   24                  38              92
# 123         124    Male   39                  69              91
# 127         128    Male   40                  71              95
# 141         142    Male   32                  75              93
# 145         146    Male   28                  77              97
# 163         164  Female   31                  81              93
# 167         168  Female   33                  86              95
# 173         174    Male   36                  87              92
# 185         186    Male   30                  99              97
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(dataset,x_vars=['Age','Annual_Income_(k$)','Gender'],y_vars='Spending_Score',height=4,kind='scatter')
plt.show()
